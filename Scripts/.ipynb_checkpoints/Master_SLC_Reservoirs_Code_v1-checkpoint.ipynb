# %%
import os
import pandas as pd
import numpy as np
import requests
import io
import json
from datetime import datetime


# %run SLC_Functions.py

# %% [markdown]
# ## Check out and read in the WL data
#
# Home page link - https://uhslc.soest.hawaii.edu/
# Data Dashboard  - https://uhslc.soest.hawaii.edu/reservoir/
#
# ####  Reservoir level data from the Sea Level center Reservoir Database gets pulled by Pull_WL_Data.ipynb

# %%
datapath = os.path.join("..", "Data/WL_Data2024-09-27/UHSLC")

# Create a metadata describe frame for the Reservoir data 
data_describe = create_metadata_from_SLC_Data(datapath)

data_describe.head()
# Out:
# C:\Users\CS\Desktop\Git_Repos\SLC_Reservoir_Data\Scripts\SLC_Functions.py:27: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join(datapath, file), parse_dates=['date'])
# C:\Users\CS\Desktop\Git_Repos\SLC_Reservoir_Data\Scripts\SLC_Functions.py:27: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join(datapath, file), parse_dates=['date'])
#    station_id                  date_min                  date_max  \
# 0    EDD00214 2018-02-07 20:09:00+00:00 2024-09-24 22:04:00+00:00
# 1    EDD00CC6 2018-02-07 20:09:00+00:00 2024-09-24 22:04:00+00:00
# 2    EDD01162 2022-04-26 22:09:00+00:00 2024-09-24 22:04:00+00:00
# 3    EDD024F8 2018-02-07 20:09:00+00:00 2024-09-24 22:04:00+00:00
# 4    EDD02A2A 2018-02-07 20:09:00+00:00 2024-09-24 22:04:00+00:00
# 5    EDD0378E 2018-02-07 20:10:00+00:00 2024-09-24 22:05:00+00:00
# 6    EDD0395C 2018-02-07 20:10:00+00:00 2024-09-24 22:05:00+00:00
# 7    EDD0411E 2018-02-07 20:10:00+00:00 2024-09-24 22:05:00+00:00
# 8    EDD04FCC 2018-02-07 20:10:00+00:00 2024-08-26 11:05:00+00:00
# 9    EDD05268 2018-02-07 20:10:00+00:00 2024-09-24 22:05:00+00:00
# 10   EDD05CBA 2018-02-07 19:45:00+00:00 2024-09-24 21:40:00+00:00
# 11   EDD067F2 2018-02-07 19:45:00+00:00 2024-09-24 21:40:00+00:00
# 12   EDD06920 2018-02-07 19:45:00+00:00 2024-09-24 21:40:00+00:00
# 13   EDD07484 2018-02-07 19:45:00+00:00 2024-09-24 21:40:00+00:00
# 14   EDD07A56 2018-02-07 20:16:00+00:00 2024-09-24 22:11:00+00:00
# 15   EDD08400 2018-02-07 20:16:00+00:00 2024-09-24 22:11:00+00:00
# 16   EDD08AD2 2019-03-21 17:16:00+00:00 2024-09-24 22:11:00+00:00
# 17   EDD099A4 2019-09-17 19:17:00+00:00 2024-09-24 22:12:00+00:00
# 18   EDD0A2EC 2019-11-07 23:17:00+00:00 2024-09-24 22:12:00+00:00
# 19   EDD0AC3E 2020-01-27 23:17:00+00:00 2024-09-24 22:12:00+00:00
# 20   EDD0B19A 2020-01-28 21:17:00+00:00 2024-09-24 22:15:00+00:00
# 21   EDD0BF48 2021-10-13 00:17:00+00:00 2024-08-27 17:46:00+00:00
# 22   EDD0C70A 2021-10-11 23:17:00+00:00 2024-09-24 22:12:00+00:00
# 23   EDD0C9D8 2022-01-13 22:18:00+00:00 2024-09-24 22:13:00+00:00
# 24   EDD0D47C 2022-01-18 22:18:00+00:00 2024-09-24 22:13:00+00:00
# 25   EDD0DAAE 2022-04-27 22:31:00+00:00 2024-09-24 21:26:00+00:00
# 26   EDD11398 2021-11-02 01:45:00+00:00 2021-11-09 20:40:00+00:00
#
#          mean_WL  median_WL    min_WL    max_WL
# 0    1471.503949     1470.0 -129570.0  130758.0
# 1     939.844389      832.0     658.0  131071.0
# 2   15342.916631     -226.0    -324.0  131071.0
# 3   38210.723606    38142.0 -108451.0  131071.0
# 4   96898.777347    97105.0  -74419.0  131071.0
# 5    3690.566571     3690.0    2616.0    4541.0
# 6    2654.375553     2668.0     438.0  131071.0
# 7    2215.619380     2212.0   -1544.0  131071.0
# 8    2266.869225     2279.0    1693.0   83852.0
# 9    2376.902706     2580.0 -111151.0   80985.0
# 10   2770.888954     1833.0     753.0  131071.0
# 11    604.382326      659.0    -421.0  131071.0
# 12  30571.334004    59726.0    -500.0  131071.0
# 13  20396.741781    22909.0     294.0   24010.0
# 14   7754.564221     7922.0 -124060.0  131071.0
# 15  35850.898626    42495.0  -28857.0  131071.0
# 16   3829.718154     2482.0     463.0  131071.0
# 17  16002.611956    16002.0    1928.0   16897.0
# 18   2657.751376     2695.0 -128576.0  128245.0
# 19   1599.998566     1611.0 -129481.0  131071.0
# 20   2056.132951     2015.0   -1477.0  131071.0
# 21   2291.862161     1427.0    1023.0  131071.0
# 22   2312.244682     1150.0     -38.0  131071.0
# 23  33715.448677      374.0 -123072.0  131071.0
# 24   1622.892964     1614.0    1475.0  131071.0
# 25  26374.416007     1003.0     952.0  131071.0
# 26    993.660202      994.0     980.0    1006.0

# %% [markdown]
# ## Convert to daily Water Level data

# %%
datapath = os.path.join("..", "Data/WL_Data2024-09-27/UHSLC")

daily_dic = process_SLC_Data_To_daily(datapath)
# Out:
# C:\Users\CS\AppData\Local\Temp\ipykernel_23072\8552126.py:21: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, parse_dates=['date'])
# C:\Users\CS\AppData\Local\Temp\ipykernel_23072\8552126.py:21: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, parse_dates=['date'])

# %% [markdown]
# ## Read In the Precip data from HCDP

# %%
RainData = pd.read_csv(os.path.join("..", 'Data/HCDP_Rainfall_Daily_Data', "HCDP_RainData2018-2024.csv"))
RainData_Meta = pd.read_csv(os.path.join("..", 'Data/HCDP_Rainfall_Daily_Data', "HCDP_Rain_METADATA_2018-2024.csv"))

# First make Arc read it as a string 
RainData_Meta["SKN"] = RainData_Meta["SKN"].astype(str)+"_R"  
RainData_Meta.to_csv(os.path.join("..", 'Data/HCDP_Rainfall_Daily_Data', "HCDP_Rain_METADATA_2018-2024_ArcrReady.csv"))

# %%
# Read in SLC Metadata File 
today = "2024-09-27"
meta = pd.read_csv(os.path.join("..", "Data", "WL_Data{}".format(today), "UHSLC_Station_Metadata.csv"))

# %% [markdown]
# ## Need to go into Arc to create the near table
